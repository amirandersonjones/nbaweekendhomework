# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import the csv file
nba_18and19 = pd.read_csv('codingtemple/week9/nbastats2018-2019.csv')

nba_18and19.head()
print(nba_18and19.columns)
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %% [markdown]
# ## What was the average age of player in the league?

# %%
nba_18and19_ages = nba_18and19['Age']
print(nba_18and19_ages)
# Out:
# 0      25
# 1      28
# 2      22
# 3      25
# 4      21
#        ..
# 516    20
# 517    26
# 518    29
# 519    22
# 520    21
# Name: Age, Length: 521, dtype: int64

# %%
#used describe all to get a big picture of the data which gives me the answer to the question
nba_18and19.describe(include='all')
# Out:
#                 Name      Height      Weight           Team         Age  \
# count            521  521.000000  521.000000            470  521.000000
# unique           521         NaN         NaN             30         NaN
# top     Alex Abrines         NaN         NaN  Atlanta Hawks         NaN
# freq               1         NaN         NaN             21         NaN
# mean             NaN   78.971209  217.516315            NaN   25.900192
# std              NaN    3.299932   23.522089            NaN    4.208236
# min              NaN   69.000000  166.000000            NaN   19.000000
# 25%              NaN   77.000000  200.000000            NaN   23.000000
# 50%              NaN   79.000000  215.000000            NaN   25.000000
# 75%              NaN   82.000000  235.000000            NaN   29.000000
# max              NaN   87.000000  290.000000            NaN   42.000000
#
#        Salary      Points      Blocks      Steals     Assists  ...  \
# ...

# %%
#filter for just age to check that I am getting the proper data.
# THE AVERAGE AGE OF PLAYERS IN THE LEAGUE IS 25.9 OR ROUNDED 26
nba_18and19.describe().loc[['mean', 'max']][['Age']]
# Out:
#             Age
# mean  25.900192
# max   42.000000

# %% [markdown]
# # What player scored the most points?

# %%
nba_18and19.groupby(['Name'])[['Points']].max().sort_values('Points', ascending=False).head()
# Out:
#                        Points
# Name
# James Harden             36.1
# Paul George              28.0
# Giannis Antetokounmpo    27.7
# Joel Embiid              27.5
# LeBron James             27.4

# %%
#  HARDEN SCORED THE MOST POINTS: 36 POINTS

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
nba_18and19.groupby(['Name'])[['Blocks']].max().sort_values('Blocks', ascending=False).head()
# Out:
#                    Blocks
# Name
# Myles Turner          2.7
# Anthony Davis         2.4
# Mitchell Robinson     2.4
# Rudy Gobert           2.3
# Brook Lopez           2.2

# %%
# MYLES TURNER HAD THE MOST BLOCKS DURING THE SEASON.

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
nba_18and19.groupby(['Name'])[['WS', 'WS48']].sum().sort_values('WS', ascending=False).head()
# Out:
#                          WS   WS48
# Name
# James Harden           15.2  0.254
# Rudy Gobert            14.4  0.268
# Giannis Antetokounmpo  14.4  0.292
# Damian Lillard         12.1  0.205
# Paul George            11.9  0.201

# %%
#  James Harden with 15.2 win shares and 0.254 WShares48

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
nba_18and19.groupby(['Name'])[['FG3%']].max().sort_values('FG3%',  ascending=False).head()
# Out:
#                 FG3%
# Name
# Eric Moreland  1.000
# Scott Machado  1.000
# Trevon Duval   1.000
# Jordan Sibert  1.000
# Troy Caupain   0.667

# %%
# JORDAN SIBERT, SCOTT MACHADO, ERIC MORELAND, AND TREVON HAD THE BEST 3-POINT PERCENTAGE EACH AT 1. WE CAN ADD THE AVERAGE

# %%
nba_18and19.groupby(['Name'])[['FG3%', 'FGA']].sum().sort_values('FG3%',  ascending=False).head()
# Out:
#                 FG3%  FGA
# Name
# Jordan Sibert  1.000  1.0
# Scott Machado  1.000  1.5
# Eric Moreland  1.000  1.4
# Trevon Duval   1.000  1.0
# Troy Caupain   0.667  2.0

# %%
# THIS TELLS A DIFFERENT STORY WHERE OF THE TOP 5 WHEN YOU INCLUDE AVERAGE THE ANSWER IS SCOTT MACHADO, 
#BUT TROY CAUPAIN WHO WAS AT THE BOTTOM OF FG% FOR THE TOP 5 HAS A BETTER AVERAGE THAN THE OTHERS. WE NEED TO EXPLORE THE 
#DIFFERENCE WHEN THE AVERAGE IS ADDED TO UNDERSTAND THIS QUESTION BETTER IF WE HAD TO PRESENT THESE STATISTICS WE NEED TO
#EXPLAIN THIS

# %% [markdown]
# # Who played the most minutes during the season

# %%
nba_18and19.groupby(['Name'])[['MP']].max().sort_values('MP',  ascending=False).head()
# Out:
#                      MP
# Name
# Bradley Beal       36.9
# Paul George        36.9
# James Harden       36.8
# Russell Westbrook  36.0
# Jrue Holiday       35.9

# %%
# BRADLEY BEAL AND PAUL GEORGE BOTH PLAYED 36.9 MINUTES and JAMES HARDEN WAS A CLOSE SECOND WITH 36.8

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nba_18and19.groupby(['Name'])[['PER']].max().sort_values('PER',  ascending=False).head()
# Out:
#                         PER
# Name
# Zhou Qi                80.4
# Trevon Duval           38.3
# Gary Payton II         36.9
# Alan Williams          32.9
# Giannis Antetokounmpo  30.9

# %%
# Zhou Qi HAD THE HIGHEST PER AT 80.4 PERCENT AND WAS THE CLUTHEST PLAYER

# %% [markdown]
# # What team had the youngest roster?

# %%
info=nba_18and19.groupby(['Team', 'Name'])[['Age']].min().sort_values('Age', ascending=False)
team=nba_18and19['Team']
m1=info.merge(team, on='Team', how='inner')

# %%
m1
# Out:
#                   Team  Age
# 0        Atlanta Hawks   42
# 1        Atlanta Hawks   42
# 2        Atlanta Hawks   42
# 3        Atlanta Hawks   42
# 4        Atlanta Hawks   42
# ...                ...  ...
# 7513  Sacramento Kings   19
# 7514  Sacramento Kings   19
# 7515  Sacramento Kings   19
# 7516  Sacramento Kings   19
# 7517  Sacramento Kings   19
#
# [7518 rows x 2 columns]

# %%
nba_18and19.groupby(['Name', 'Team'])[['Age']].min().sort_values('Age',  ascending=False)
# Out:
#                                        Age
# Name               Team
# Vince Carter       Atlanta Hawks        42
# Dirk Nowitzki      Dallas Mavericks     40
# Jamal Crawford     Atlanta Hawks        38
# Pau Gasol          San Antonio Spurs    38
# Udonis Haslem      Miami Heat           38
# ...                                    ...
# Kevin Knox         New York Knicks      19
# Wendell Carter Jr. Chicago Bulls        19
# Troy Brown Jr.     Washington Wizards   19
# Luka Doncic        Dallas Mavericks     19
# Jarred Vanderbilt  Denver Nuggets       19
#
# [470 rows x 1 columns]

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
# nba_18and19.groupby(['Name', 'Team'])[['Salary']].max().sort_values('Salary',  ascending=False).head()
#this doesnt seem right??
#Dwight Powel of the Dallas Mavericks

# %%
nba_18and19.groupby(['Team'])[['Salary']].max()
# Out:
#                          Salary
# Team
# Atlanta Hawks             94742
# Boston Celtics            92857
# Brooklyn Nets           9530000
# Charlotte Hornets        988464
# Chicago Bulls             88531
# Cleveland Cavaliers     9607500
# Dallas Mavericks        9631250
# Denver Nuggets           838464
# Detroit Pistons          838464
# Golden State Warriors   8307692
# Houston Rockets           90005
# Indiana Pacers           838464
# Los Angeles Clippers    8000000
# Los Angeles Lakers      9000000
# Memphis Grizzlies       8641000
# Miami Heat              9367200
# Milwaukee Bucks         7000000
# Minnesota Timberwolves  8575916
# New Orleans Pelicans    8808685
# New York Knicks         7119650
# Oklahoma City Thunder   8653847
# Orlando Magic            838464
# Philadelphia 76ers      7000000
# Phoenix Suns             949000
# Portland Trail Blazers   838464
# Sacramento Kings        9000000
# San Antonio Spurs        838464
# Toronto Raptors         9367200
# ...

# %%
nba_18and19.groupby(['Team'])[['Name']].count()
# Out:
#                         Name
# Team
# Atlanta Hawks             21
# Boston Celtics            15
# Brooklyn Nets             18
# Charlotte Hornets         14
# Chicago Bulls             16
# Cleveland Cavaliers       16
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           13
# Indiana Pacers            17
# Los Angeles Clippers      19
# Los Angeles Lakers        16
# Memphis Grizzlies         17
# Miami Heat                11
# Milwaukee Bucks           14
# Minnesota Timberwolves    16
# New Orleans Pelicans      18
# New York Knicks           16
# Oklahoma City Thunder     12
# Orlando Magic             15
# Philadelphia 76ers        17
# Phoenix Suns              21
# Portland Trail Blazers    14
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           12
# Utah Jazz                 15
# Washington Wizards        17

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nba_18and19.groupby(['Name'])[['FG3%', 'FGA']].sum().sort_values('FG3%',  ascending=True).head()
# Out:
#                     FG3%  FGA
# Name
# Johnathan Williams   0.0  4.6
# Joe Chealey          0.0  3.0
# Joakim Noah          0.0  5.1
# Jimmer Fredette      0.0  4.8
# Jawun Evans          0.0  1.8

# %%
nba_18and19[nba_18and19['Name'] == 'Jawun Evans']
# Out:
#             Name  Height  Weight                  Team  Age   Salary  Points  \
# 155  Jawun Evans      72     185  Los Angeles Clippers   22  1378242     0.8
#
#      Blocks  Steals  Assists  ...  G  PER  OWS  DWS   WS   WS48   USG   BPM  \
# 155     0.0     0.4      1.3  ...  8  0.1 -0.2  0.0 -0.2 -0.151  13.2 -10.5
#
#      VORP         Names
# 155  -0.1  Myles Turner
#
# [1 rows x 28 columns]

# %%
#THE ANSWER SEEMS TO BE JAWUN EVANS?
